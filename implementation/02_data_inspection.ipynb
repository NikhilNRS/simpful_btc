# %%
import pandas as pd

# Assuming the CSV file is named 'raw_integrated_data.csv' and located within a 'data' folder at the same level as our Jupyter notebook
file_path = 'data/raw_integrated_data.csv'
df = pd.read_csv(file_path, parse_dates=['timestamp'])
# Out:
# /var/folders/jt/f0dtwp_x2w1fvk06tzwm2p200000gn/T/ipykernel_47172/3606079187.py:5: DtypeWarning: Columns (48,50,51,53,54,55,56) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, parse_dates=['timestamp'])

# %%
# Basic structure and data types
print(df.info())

# Preliminary statistics
print(df.describe())

# Quick assessment of missing values per column
print(df.isnull().sum())

# Preview the dataset
print(df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75778 entries, 0 to 75777
# Data columns (total 57 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   timestamp                                           75778 non-null  datetime64[ns]
#  1   low                                                 75778 non-null  float64
#  2   high                                                75778 non-null  float64
#  3   open                                                75778 non-null  float64
#  4   close                                               75778 non-null  float64
#  5   volume                                              75778 non-null  float64
#  6   sma_30                                              75778 non-null  float64
#  7   rsi                                                 75778 non-null  float64
#  8   macd                                                75778 non-null  float64
#  9   dia_open                                            31845 non-null  float64
#  10  dia_high                                            31845 non-null  float64
#  11  dia_low                                             31845 non-null  float64
#  12  dia_close                                           31845 non-null  float64
#  13  dia_volume                                          31845 non-null  float64
#  14  gld_open                                            33608 non-null  float64
#  15  gld_high                                            33608 non-null  float64
#  16  gld_low                                             33608 non-null  float64
#  17  gld_close                                           33608 non-null  float64
#  18  gld_volume                                          33608 non-null  float64
#  19  spy_open                                            36087 non-null  float64
#  20  spy_high                                            36087 non-null  float64
#  21  spy_low                                             36087 non-null  float64
#  22  spy_close                                           36087 non-null  float64
#  23  spy_volume                                          36087 non-null  float64
#  24  federal_funds_rate_daily                            3133 non-null   float64
#  25  treasury_yield_daily                                2235 non-null   float64
#  26  cpi_monthly                                         101 non-null    float64
#  27  durables_monthly                                    100 non-null    float64
#  28  nonfarm_payroll_monthly                             101 non-null    float64
#  29  real_gdp_per_capita_quarterly                       33 non-null     float64
#  30  real_gdp_quarterly                                  33 non-null     float64
#  31  retail_sales_monthly                                101 non-null    float64
#  32  unemployment_monthly                                101 non-null    float64
#  33  central_bank_policy_rate_prcnt                      6 non-null      float64
#  34  domestic_credit_gdp                                 6 non-null      float64
#  35  foreign_direct_investment_value                     6 non-null      float64
#  36  gdp_growth_annual_prcnt                             6 non-null      float64
#  37  inflation_rate_value                                6 non-null      float64
#  38  individuals_using_the_internet_prcnt_of_population  6 non-null      float64
#  39  mobile_cellular_subscriptions_per_100_people        6 non-null      float64
#  40  personal_remittances_received_prcnt_of_gdp          6 non-null      float64
#  41  stock_market_index_value                            6 non-null      float64
#  42  tariffs_value                                       5 non-null      float64
#  43  total_public_debt_gdp_value                         6 non-null      float64
#  44  trade_balance_value                                 6 non-null      float64
#  45  trade_in_services_value                             6 non-null      float64
#  46  unemployment_rate_value                             6 non-null      float64
#  47  value                                               53594 non-null  float64
#  48  classification                                      53594 non-null  object
#  49  id                                                  1433 non-null   float64
#  50  title                                               1433 non-null   object
#  51  url                                                 1433 non-null   object
#  52  sentiment_score                                     1433 non-null   float64
#  53  sentiment_interpretation                            1433 non-null   object
#  54  author                                              1433 non-null   object
#  55  timestamp_news                                      1433 non-null   object
#  56  timestamp_rounded                                   1433 non-null   object
# dtypes: datetime64[ns](1), float64(49), object(7)
# memory usage: 33.0+ MB
# None
#                            timestamp           low          high  \
# count                          75778  75778.000000  75778.000000
# mean   2019-11-15 00:18:55.659426304  16378.040296  16544.213813
# min              2015-07-22 02:00:00      0.060000    207.380000
# 25%              2017-09-18 20:15:00   3574.137500   3595.002500
# 50%              2019-11-18 09:30:00   9338.165000   9418.000000
# 75%              2022-01-15 20:45:00  27165.472500  27325.640000
# max              2024-02-06 16:00:00  68456.500000  69000.000000
# std                              NaN  16400.630039  16573.756973
#
#                open         close        volume        sma_30           rsi  \
# count  75778.000000  75778.000000  75778.000000  75778.000000  75778.000000
# mean   16464.002574  16464.461536    612.862065  16456.249763     51.373208
# min        0.060000    200.000000      0.280000    214.430333      1.801767
# 25%     3585.192500   3585.495000    213.081213   3584.060917     40.759884
# 50%     9379.760000   9379.995000    382.695626   9365.727333     51.409833
# 75%    27237.190000  27239.787500    729.283747  27186.944750     61.961334
# max    68638.470000  68639.630000  31505.461253  67445.454000     99.110974
# std    16489.959668  16489.951482    779.372228  16482.472468     16.051468
#
#                macd      dia_open  ...  \
# count  75778.000000  31845.000000  ...
# mean       3.979881    256.093441  ...
# min    -2338.952888    131.290000  ...
# 25%      -25.340809    210.762000  ...
# 50%        0.634657    248.066000  ...
# 75%       34.746347    324.607000  ...
# max     1887.086442    376.711000  ...
# std      191.767472     67.114337  ...
#
#        personal_remittances_received_prcnt_of_gdp  stock_market_index_value  \
# count                                    6.000000                  6.000000
# mean                                     0.032718                 15.791241
# min                                      0.030671                 -6.237260
# 25%                                      0.032459                 11.215992
# 50%                                      0.032778                 17.839443
# 75%                                      0.033595                 25.024543
# max                                      0.033859                 28.878069
# std                                      0.001170                 12.901859
#
#        tariffs_value  total_public_debt_gdp_value  trade_balance_value  \
# count       5.000000                     6.000000         6.000000e+00
# mean        4.188000                   107.111305        -6.171353e+11
# min         2.760000                    97.692936        -8.582390e+11
# 25%         2.870000                    98.643320        -6.180625e+11
# 50%         3.250000                    99.933009        -5.857905e+11
# 75%         3.360000                   115.472367        -5.521228e+11
# max         8.700000                   126.243301        -5.032720e+11
# std         2.534752                    12.719801         1.254592e+11
#
#        trade_in_services_value  unemployment_rate_value         value  \
# count                 6.000000                 6.000000  53594.000000
# mean                  6.582337                 5.033333     44.510617
# min                   5.662726                 3.670000      5.000000
# 25%                   6.109746                 4.015000     26.000000
# 50%                   6.939075                 4.615000     42.000000
# 75%                   6.962494                 5.230000     61.000000
# max                   7.149545                 8.050000     95.000000
# std                   0.652764                 1.601483     21.436449
#
#                id  sentiment_score
# count  1433.00000      1433.000000
# mean    717.00000         0.097510
# min       1.00000        -0.527529
# 25%     359.00000        -0.017332
# 50%     717.00000         0.106259
# 75%    1075.00000         0.208790
# max    1433.00000         0.596255
# std     413.81578         0.157854
#
# [8 rows x 50 columns]
# timestamp                                                 0
# low                                                       0
# high                                                      0
# open                                                      0
# close                                                     0
# volume                                                    0
# sma_30                                                    0
# rsi                                                       0
# macd                                                      0
# dia_open                                              43933
# dia_high                                              43933
# dia_low                                               43933
# dia_close                                             43933
# dia_volume                                            43933
# gld_open                                              42170
# gld_high                                              42170
# gld_low                                               42170
# gld_close                                             42170
# gld_volume                                            42170
# spy_open                                              39691
# spy_high                                              39691
# spy_low                                               39691
# spy_close                                             39691
# spy_volume                                            39691
# federal_funds_rate_daily                              72645
# treasury_yield_daily                                  73543
# cpi_monthly                                           75677
# durables_monthly                                      75678
# nonfarm_payroll_monthly                               75677
# real_gdp_per_capita_quarterly                         75745
# real_gdp_quarterly                                    75745
# retail_sales_monthly                                  75677
# unemployment_monthly                                  75677
# central_bank_policy_rate_prcnt                        75772
# domestic_credit_gdp                                   75772
# foreign_direct_investment_value                       75772
# gdp_growth_annual_prcnt                               75772
# inflation_rate_value                                  75772
# individuals_using_the_internet_prcnt_of_population    75772
# mobile_cellular_subscriptions_per_100_people          75772
# personal_remittances_received_prcnt_of_gdp            75772
# stock_market_index_value                              75772
# tariffs_value                                         75773
# total_public_debt_gdp_value                           75772
# trade_balance_value                                   75772
# trade_in_services_value                               75772
# unemployment_rate_value                               75772
# value                                                 22184
# classification                                        22184
# id                                                    74345
# title                                                 74345
# url                                                   74345
# sentiment_score                                       74345
# sentiment_interpretation                              74345
# author                                                74345
# timestamp_news                                        74345
# timestamp_rounded                                     74345
# dtype: int64
#             timestamp     low    high    open   close      volume      sma_30  \
# 0 2015-07-22 02:00:00  276.01  276.89  276.56  276.42  166.841611  279.333667
# 1 2015-07-22 03:00:00  276.21  277.16  276.58  276.91  241.774294  279.297333
# 2 2015-07-22 04:00:00  276.31  276.95  276.85  276.40  171.778578  279.239333
# 3 2015-07-22 05:00:00  275.51  276.81  276.38  275.81  229.820689  279.099667
# 4 2015-07-22 06:00:00  275.01  276.79  275.74  276.04  307.507227  278.938000
#
#          rsi      macd  dia_open  ...  value  classification  id  title  url  \
# 0  24.211767 -0.510280       NaN  ...    NaN             NaN NaN    NaN  NaN
# 1  32.886011 -0.578152       NaN  ...    NaN             NaN NaN    NaN  NaN
# 2  28.911993 -0.665423       NaN  ...    NaN             NaN NaN    NaN  NaN
# 3  24.896118 -0.773281       NaN  ...    NaN             NaN NaN    NaN  NaN
# 4  29.312518 -0.830624   149.183  ...    NaN             NaN NaN    NaN  NaN
#
#    sentiment_score  sentiment_interpretation  author  timestamp_news  \
# 0              NaN                       NaN     NaN             NaN
# 1              NaN                       NaN     NaN             NaN
# 2              NaN                       NaN     NaN             NaN
# 3              NaN                       NaN     NaN             NaN
# 4              NaN                       NaN     NaN             NaN
#
#    timestamp_rounded
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
#
# [5 rows x 57 columns]

# %% [markdown]
# # Helper Functions

# %%
def first_measurement_time(df):
    first_measurements = {}
    for column in df.columns:
        # Ignoring non-numeric and timestamp columns for "first measurement" context
        if df[column].dtype == 'object' or column == 'timestamp':
            continue
        non_null_data = df[df[column].notnull()]
        if not non_null_data.empty:
            first_measurements[column] = non_null_data['timestamp'].min()
    return first_measurements

# %%
import numpy as np

def average_interval_between_measurements(df):
    average_intervals = {}
    for column in df.columns:
        # Ignoring non-numeric and timestamp columns for "average interval" context
        if df[column].dtype == 'object' or column == 'timestamp':
            continue
        non_null_data = df[df[column].notnull()]
        if non_null_data.shape[0] > 1:
            # Calculate differences between consecutive non-null timestamps
            time_diffs = non_null_data['timestamp'].diff().dropna()
            # Convert time differences to a compatible numeric format, e.g., hours
            average_interval = time_diffs.mean()
            average_intervals[column] = average_interval
        else:
            average_intervals[column] = np.nan  # Indicates a single measurement or none
    return average_intervals

# %%
# Call the functions on our dataset
first_measurement_times = first_measurement_time(df)
average_intervals = average_interval_between_measurements(df)

# Convert the outputs to DataFrames for easy sharing
first_measurement_table = pd.DataFrame(list(first_measurement_times.items()), columns=['Variable', 'First Measurement Time'])
average_interval_table = pd.DataFrame(list(average_intervals.items()), columns=['Variable', 'Average Interval Between Measurements'])

# Display the tables
print("First Measurement Time for Each Variable:")
print(first_measurement_table)
print("\nAverage Interval Between Measurements for Each Variable:")
print(average_interval_table)
# Out:
# First Measurement Time for Each Variable:
#                                              Variable First Measurement Time
# 0                                                 low    2015-07-22 02:00:00
# 1                                                high    2015-07-22 02:00:00
# 2                                                open    2015-07-22 02:00:00
# 3                                               close    2015-07-22 02:00:00
# 4                                              volume    2015-07-22 02:00:00
# 5                                              sma_30    2015-07-22 02:00:00
# 6                                                 rsi    2015-07-22 02:00:00
# 7                                                macd    2015-07-22 02:00:00
# 8                                            dia_open    2015-07-22 06:00:00
# 9                                            dia_high    2015-07-22 06:00:00
# 10                                            dia_low    2015-07-22 06:00:00
# 11                                          dia_close    2015-07-22 06:00:00
# 12                                         dia_volume    2015-07-22 06:00:00
# 13                                           gld_open    2015-07-22 04:00:00
# 14                                           gld_high    2015-07-22 04:00:00
# 15                                            gld_low    2015-07-22 04:00:00
# 16                                          gld_close    2015-07-22 04:00:00
# 17                                         gld_volume    2015-07-22 04:00:00
# 18                                           spy_open    2015-07-22 04:00:00
# 19                                           spy_high    2015-07-22 04:00:00
# 20                                            spy_low    2015-07-22 04:00:00
# 21                                          spy_close    2015-07-22 04:00:00
# 22                                         spy_volume    2015-07-22 04:00:00
# 23                           federal_funds_rate_daily    2015-07-23 00:00:00
# 24                               treasury_yield_daily    2015-07-23 00:00:00
# 25                                        cpi_monthly    2015-08-01 00:00:00
# 26                                   durables_monthly    2015-08-01 00:00:00
# 27                            nonfarm_payroll_monthly    2015-08-01 00:00:00
# 28                      real_gdp_per_capita_quarterly    2015-10-01 00:00:00
# 29                                 real_gdp_quarterly    2015-10-01 00:00:00
# 30                               retail_sales_monthly    2015-08-01 00:00:00
# 31                               unemployment_monthly    2015-08-01 00:00:00
# 32                     central_bank_policy_rate_prcnt    2016-01-01 00:00:00
# 33                                domestic_credit_gdp    2016-01-01 00:00:00
# 34                    foreign_direct_investment_value    2016-01-01 00:00:00
# 35                            gdp_growth_annual_prcnt    2016-01-01 00:00:00
# 36                               inflation_rate_value    2016-01-01 00:00:00
# 37  individuals_using_the_internet_prcnt_of_popula...    2016-01-01 00:00:00
# 38       mobile_cellular_subscriptions_per_100_people    2016-01-01 00:00:00
# 39         personal_remittances_received_prcnt_of_gdp    2016-01-01 00:00:00
# 40                           stock_market_index_value    2016-01-01 00:00:00
# 41                                      tariffs_value    2016-01-01 00:00:00
# 42                        total_public_debt_gdp_value    2016-01-01 00:00:00
# 43                                trade_balance_value    2016-01-01 00:00:00
# 44                            trade_in_services_value    2016-01-01 00:00:00
# 45                            unemployment_rate_value    2016-01-01 00:00:00
# 46                                              value    2018-02-01 00:00:00
# 47                                                 id    2022-12-16 14:00:00
# 48                                    sentiment_score    2022-12-16 14:00:00
#
# Average Interval Between Measurements for Each Variable:
#                                              Variable  \
# 0                                                 low
# 1                                                high
# 2                                                open
# 3                                               close
# 4                                              volume
# 5                                              sma_30
# 6                                                 rsi
# 7                                                macd
# 8                                            dia_open
# 9                                            dia_high
# 10                                            dia_low
# 11                                          dia_close
# 12                                         dia_volume
# 13                                           gld_open
# 14                                           gld_high
# 15                                            gld_low
# 16                                          gld_close
# 17                                         gld_volume
# 18                                           spy_open
# 19                                           spy_high
# 20                                            spy_low
# 21                                          spy_close
# 22                                         spy_volume
# 23                           federal_funds_rate_daily
# 24                               treasury_yield_daily
# 25                                        cpi_monthly
# 26                                   durables_monthly
# 27                            nonfarm_payroll_monthly
# 28                      real_gdp_per_capita_quarterly
# 29                                 real_gdp_quarterly
# 30                               retail_sales_monthly
# 31                               unemployment_monthly
# 32                     central_bank_policy_rate_prcnt
# 33                                domestic_credit_gdp
# 34                    foreign_direct_investment_value
# 35                            gdp_growth_annual_prcnt
# 36                               inflation_rate_value
# 37  individuals_using_the_internet_prcnt_of_popula...
# 38       mobile_cellular_subscriptions_per_100_people
# 39         personal_remittances_received_prcnt_of_gdp
# 40                           stock_market_index_value
# 41                                      tariffs_value
# 42                        total_public_debt_gdp_value
# 43                                trade_balance_value
# 44                            trade_in_services_value
# 45                            unemployment_rate_value
# 46                                              value
# 47                                                 id
# 48                                    sentiment_score
#
#    Average Interval Between Measurements
# 0              0 days 00:59:19.190783483
# 1              0 days 00:59:19.190783483
# 2              0 days 00:59:19.190783483
# 3              0 days 00:59:19.190783483
# 4              0 days 00:59:19.190783483
# 5              0 days 00:59:19.190783483
# 6              0 days 00:59:19.190783483
# 7              0 days 00:59:19.190783483
# 8              0 days 02:19:23.748272830
# 9              0 days 02:19:23.748272830
# 10             0 days 02:19:23.748272830
# 11             0 days 02:19:23.748272830
# 12             0 days 02:19:23.748272830
# 13             0 days 02:12:05.206058261
# 14             0 days 02:12:05.206058261
# 15             0 days 02:12:05.206058261
# 16             0 days 02:12:05.206058261
# 17             0 days 02:12:05.206058261
# 18             0 days 02:03:00.768164939
# 19             0 days 02:03:00.768164939
# 20             0 days 02:03:00.768164939
# 21             0 days 02:03:00.768164939
# 22             0 days 02:03:00.768164939
# 23             0 days 23:54:28.965517241
# 24             1 days 09:31:06.069829901
# 25                      30 days 18:00:00
# 26            30 days 17:56:21.818181818
# 27                      30 days 18:00:00
# 28                      91 days 07:30:00
# 29                      91 days 07:30:00
# 30                      30 days 18:00:00
# 31                      30 days 18:00:00
# 32                     365 days 09:36:00
# 33                     365 days 09:36:00
# 34                     365 days 09:36:00
# 35                     365 days 09:36:00
# 36                     365 days 09:36:00
# 37                     365 days 09:36:00
# 38                     365 days 09:36:00
# 39                     365 days 09:36:00
# 40                     365 days 09:36:00
# 41                     365 days 06:00:00
# 42                     365 days 09:36:00
# 43                     365 days 09:36:00
# 44                     365 days 09:36:00
# 45                     365 days 09:36:00
# 46             0 days 00:59:01.358013173
# 47             0 days 06:22:32.513966480
# 48             0 days 06:22:32.513966480

# %%
def are_timestamps_round_hours(df):
    """
    Checks if all timestamps in the 'timestamp' column of the dataframe are on a round hour.
    
    Parameters:
    df (pd.DataFrame): Dataframe with a 'timestamp' column.
    
    Returns:
    bool: True if all timestamps are on a round hour, False otherwise.
    """
    # Extract minutes and seconds from each timestamp
    minutes = df['timestamp'].dt.minute
    seconds = df['timestamp'].dt.second
    
    # Check if all minutes and seconds are 0
    all_round_hours = (minutes == 0) & (seconds == 0)
    
    return all_round_hours.all()

result = are_timestamps_round_hours(df)
print("All timestamps are on a round hour:", result)
# Out:
# All timestamps are on a round hour: True

# %%
def forward_fill_from_first_measurement(df):
    """
    Forward fills missing values for each column in the DataFrame from the first
    non-null value observed for that column.
    
    Parameters:
    df (pd.DataFrame): The DataFrame with variables across different intervals.
    
    Returns:
    pd.DataFrame: The DataFrame after applying the forward fill operation.
    """
    filled_df = df.copy()
    for column in filled_df.columns:
        if column != 'timestamp':  # Exclude the 'timestamp' column from filling
            # Forward fill the column, starting from the first non-null value
            filled_df[column] = filled_df[column].ffill()
    
    return filled_df

filled_df = forward_fill_from_first_measurement(df)

# %% [markdown]
# # Count missing values for every column

# %%
missing_values_after_fill = filled_df.isnull().sum()

# Display the count of missing values for each column
print("Missing values for each column after forward fill:")
print(missing_values_after_fill)
# Out:
# Missing values for each column after forward fill:
# timestamp                                                 0
# low                                                       0
# high                                                      0
# open                                                      0
# close                                                     0
# volume                                                    0
# sma_30                                                    0
# rsi                                                       0
# macd                                                      0
# dia_open                                                  4
# dia_high                                                  4
# dia_low                                                   4
# dia_close                                                 4
# dia_volume                                                4
# gld_open                                                  2
# gld_high                                                  2
# gld_low                                                   2
# gld_close                                                 2
# gld_volume                                                2
# spy_open                                                  2
# spy_high                                                  2
# spy_low                                                   2
# spy_close                                                 2
# spy_volume                                                2
# federal_funds_rate_daily                                 22
# treasury_yield_daily                                     22
# cpi_monthly                                             238
# durables_monthly                                        238
# nonfarm_payroll_monthly                                 238
# real_gdp_per_capita_quarterly                          1702
# real_gdp_quarterly                                     1702
# retail_sales_monthly                                    238
# unemployment_monthly                                    238
# central_bank_policy_rate_prcnt                         3910
# domestic_credit_gdp                                    3910
# foreign_direct_investment_value                        3910
# gdp_growth_annual_prcnt                                3910
# inflation_rate_value                                   3910
# individuals_using_the_internet_prcnt_of_population     3910
# mobile_cellular_subscriptions_per_100_people           3910
# personal_remittances_received_prcnt_of_gdp             3910
# stock_market_index_value                               3910
# tariffs_value                                          3910
# total_public_debt_gdp_value                            3910
# trade_balance_value                                    3910
# trade_in_services_value                                3910
# unemployment_rate_value                                3910
# value                                                 22184
# classification                                        22184
# id                                                    64866
# title                                                 64866
# url                                                   64866
# sentiment_score                                       64866
# sentiment_interpretation                              64866
# author                                                64866
# timestamp_news                                        64866
# timestamp_rounded                                     64866
# dtype: int64

# %%
# In order to avoid backfilling filter events starting from 2016

# %%
# 'timestamp' is the name of our datetime column in the filled_df DataFrame
filled_df_filtered = filled_df[filled_df['timestamp'] >= '2016-01-01']

# %%
# Basic structure and data types
print(filled_df_filtered.info())

# Preliminary statistics
print(filled_df_filtered.describe())

# Quick assessment of missing values per column
print(filled_df_filtered.isnull().sum())

# Preview the dataset
print(filled_df_filtered.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 71868 entries, 3910 to 75777
# Data columns (total 57 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   timestamp                                           71868 non-null  datetime64[ns]
#  1   low                                                 71868 non-null  float64
#  2   high                                                71868 non-null  float64
#  3   open                                                71868 non-null  float64
#  4   close                                               71868 non-null  float64
#  5   volume                                              71868 non-null  float64
#  6   sma_30                                              71868 non-null  float64
#  7   rsi                                                 71868 non-null  float64
#  8   macd                                                71868 non-null  float64
#  9   dia_open                                            71868 non-null  float64
#  10  dia_high                                            71868 non-null  float64
#  11  dia_low                                             71868 non-null  float64
#  12  dia_close                                           71868 non-null  float64
#  13  dia_volume                                          71868 non-null  float64
#  14  gld_open                                            71868 non-null  float64
#  15  gld_high                                            71868 non-null  float64
#  16  gld_low                                             71868 non-null  float64
#  17  gld_close                                           71868 non-null  float64
#  18  gld_volume                                          71868 non-null  float64
#  19  spy_open                                            71868 non-null  float64
#  20  spy_high                                            71868 non-null  float64
#  21  spy_low                                             71868 non-null  float64
#  22  spy_close                                           71868 non-null  float64
#  23  spy_volume                                          71868 non-null  float64
#  24  federal_funds_rate_daily                            71868 non-null  float64
#  25  treasury_yield_daily                                71868 non-null  float64
#  26  cpi_monthly                                         71868 non-null  float64
#  27  durables_monthly                                    71868 non-null  float64
#  28  nonfarm_payroll_monthly                             71868 non-null  float64
#  29  real_gdp_per_capita_quarterly                       71868 non-null  float64
#  30  real_gdp_quarterly                                  71868 non-null  float64
#  31  retail_sales_monthly                                71868 non-null  float64
#  32  unemployment_monthly                                71868 non-null  float64
#  33  central_bank_policy_rate_prcnt                      71868 non-null  float64
#  34  domestic_credit_gdp                                 71868 non-null  float64
#  35  foreign_direct_investment_value                     71868 non-null  float64
#  36  gdp_growth_annual_prcnt                             71868 non-null  float64
#  37  inflation_rate_value                                71868 non-null  float64
#  38  individuals_using_the_internet_prcnt_of_population  71868 non-null  float64
#  39  mobile_cellular_subscriptions_per_100_people        71868 non-null  float64
#  40  personal_remittances_received_prcnt_of_gdp          71868 non-null  float64
#  41  stock_market_index_value                            71868 non-null  float64
#  42  tariffs_value                                       71868 non-null  float64
#  43  total_public_debt_gdp_value                         71868 non-null  float64
#  44  trade_balance_value                                 71868 non-null  float64
#  45  trade_in_services_value                             71868 non-null  float64
#  46  unemployment_rate_value                             71868 non-null  float64
#  47  value                                               53594 non-null  float64
#  48  classification                                      53594 non-null  object
#  49  id                                                  10912 non-null  float64
#  50  title                                               10912 non-null  object
#  51  url                                                 10912 non-null  object
#  52  sentiment_score                                     10912 non-null  float64
#  53  sentiment_interpretation                            10912 non-null  object
#  54  author                                              10912 non-null  object
#  55  timestamp_news                                      10912 non-null  object
#  56  timestamp_rounded                                   10912 non-null  object
# dtypes: datetime64[ns](1), float64(49), object(7)
# memory usage: 31.8+ MB
# None
#                            timestamp           low          high  \
# count                          71868  71868.000000  71868.000000
# mean   2020-02-04 09:01:13.434630400  17252.621928  17427.698877
# min              2016-01-01 00:00:00      0.060000    360.870000
# 25%              2018-01-19 04:45:00   4233.097500   4289.440000
# 50%              2020-02-07 21:30:00   9850.340000   9958.860000
# 75%              2022-02-25 14:15:00  28025.917500  28270.515000
# max              2024-02-06 16:00:00  68456.500000  69000.000000
# std                              NaN  16394.825265  16568.230561
#
#                open         close        volume        sma_30           rsi  \
# count  71868.000000  71868.000000  71868.000000  71868.000000  71868.000000
# mean   17343.186677  17343.668705    624.809223  17335.040231     51.346508
# min        0.060000    353.900000      0.286254    370.865000      1.801767
# 25%     4259.852500   4259.982500    217.016828   4247.369417     40.709898
# 50%     9906.910000   9908.090000    394.317127   9918.322000     51.388982
# 75%    28145.280000  28150.452500    750.146840  28080.910750     61.947580
# max    68638.470000  68639.630000  19591.576090  67445.454000     99.110974
# std    16484.289733  16484.257250    757.122981  16476.799498     16.065958
#
#                macd      dia_open  ...  \
# count  71868.000000  71868.000000  ...
# mean       4.181957    257.661344  ...
# min    -2338.952888    131.606000  ...
# 25%      -29.394244    212.282000  ...
# 50%        0.848029    247.574000  ...
# 75%       39.198923    324.934000  ...
# max     1887.086442    376.711000  ...
# std      196.911855     65.627105  ...
#
#        personal_remittances_received_prcnt_of_gdp  stock_market_index_value  \
# count                                71868.000000              71868.000000
# mean                                     0.032168                 18.776646
# min                                      0.030671                 -6.237260
# 25%                                      0.030671                 16.258922
# 50%                                      0.032416                 26.892736
# 75%                                      0.032969                 26.892736
# max                                      0.033859                 28.878069
# std                                      0.001287                 11.202290
#
#        tariffs_value  total_public_debt_gdp_value  trade_balance_value  \
# count   71868.000000                 71868.000000         7.186800e+04
# mean        3.672781                   110.677235        -6.818791e+11
# min         2.760000                    97.692936        -8.582390e+11
# 25%         2.870000                    99.060976        -8.582390e+11
# 50%         2.870000                   120.361476        -6.263910e+11
# 75%         3.250000                   120.361476        -5.785040e+11
# max         8.700000                   126.243301        -5.032720e+11
# std         1.882909                    11.538518         1.449714e+11
#
#        trade_in_services_value  unemployment_rate_value         value  \
# count             71868.000000             71868.000000  53594.000000
# mean                  6.381134                 5.119730     44.510617
# min                   5.662726                 3.670000      5.000000
# 25%                   5.834636                 4.360000     26.000000
# 50%                   5.834636                 5.350000     42.000000
# 75%                   6.943074                 5.350000     61.000000
# max                   7.149545                 8.050000     95.000000
# std                   0.607898                 1.258848     21.436449
#
#                  id  sentiment_score
# count  10912.000000     10912.000000
# mean     166.978922         0.037805
# min        1.000000        -0.527529
# 25%        2.000000         0.004942
# 50%        2.000000         0.004942
# 75%        2.000000         0.004942
# max     1433.000000         0.596255
# std      341.655155         0.091444
#
# [8 rows x 50 columns]
# timestamp                                                 0
# low                                                       0
# high                                                      0
# open                                                      0
# close                                                     0
# volume                                                    0
# sma_30                                                    0
# rsi                                                       0
# macd                                                      0
# dia_open                                                  0
# dia_high                                                  0
# dia_low                                                   0
# dia_close                                                 0
# dia_volume                                                0
# gld_open                                                  0
# gld_high                                                  0
# gld_low                                                   0
# gld_close                                                 0
# gld_volume                                                0
# spy_open                                                  0
# spy_high                                                  0
# spy_low                                                   0
# spy_close                                                 0
# spy_volume                                                0
# federal_funds_rate_daily                                  0
# treasury_yield_daily                                      0
# cpi_monthly                                               0
# durables_monthly                                          0
# nonfarm_payroll_monthly                                   0
# real_gdp_per_capita_quarterly                             0
# real_gdp_quarterly                                        0
# retail_sales_monthly                                      0
# unemployment_monthly                                      0
# central_bank_policy_rate_prcnt                            0
# domestic_credit_gdp                                       0
# foreign_direct_investment_value                           0
# gdp_growth_annual_prcnt                                   0
# inflation_rate_value                                      0
# individuals_using_the_internet_prcnt_of_population        0
# mobile_cellular_subscriptions_per_100_people              0
# personal_remittances_received_prcnt_of_gdp                0
# stock_market_index_value                                  0
# tariffs_value                                             0
# total_public_debt_gdp_value                               0
# trade_balance_value                                       0
# trade_in_services_value                                   0
# unemployment_rate_value                                   0
# value                                                 18274
# classification                                        18274
# id                                                    60956
# title                                                 60956
# url                                                   60956
# sentiment_score                                       60956
# sentiment_interpretation                              60956
# author                                                60956
# timestamp_news                                        60956
# timestamp_rounded                                     60956
# dtype: int64
#                timestamp     low    high    open   close      volume  \
# 3910 2016-01-01 00:00:00  430.35  431.82  430.35  430.61  160.179593
# 3911 2016-01-01 01:00:00  430.00  430.98  430.59  430.78   92.132315
# 3912 2016-01-01 02:00:00  430.50  430.89  430.80  430.62   93.024327
# 3913 2016-01-01 03:00:00  430.31  432.84  430.62  432.84  103.811532
# 3914 2016-01-01 04:00:00  432.72  437.15  432.74  436.12  363.875951
#
#           sma_30        rsi      macd  dia_open  ...  value  classification  \
# 3910  427.471667  56.564580  1.190551   147.317  ...    NaN             NaN
# 3911  427.600333  57.507715  1.174780   147.317  ...    NaN             NaN
# 3912  427.682000  56.182907  1.136271   147.317  ...    NaN             NaN
# 3913  427.869000  67.989018  1.270246   147.317  ...    NaN             NaN
# 3914  428.126000  78.064719  1.622389   147.317  ...    NaN             NaN
#
#       id  title  url  sentiment_score  sentiment_interpretation  author  \
# 3910 NaN    NaN  NaN              NaN                       NaN     NaN
# 3911 NaN    NaN  NaN              NaN                       NaN     NaN
# 3912 NaN    NaN  NaN              NaN                       NaN     NaN
# 3913 NaN    NaN  NaN              NaN                       NaN     NaN
# 3914 NaN    NaN  NaN              NaN                       NaN     NaN
#
#       timestamp_news  timestamp_rounded
# 3910             NaN                NaN
# 3911             NaN                NaN
# 3912             NaN                NaN
# 3913             NaN                NaN
# 3914             NaN                NaN
#
# [5 rows x 57 columns]

# %% [markdown]
# # Final validation checks

# %%
# Identifying and reporting duplicate rows
duplicates_all = filled_df_filtered.duplicated().sum()
timestamp_duplicates = filled_df_filtered.duplicated(subset=['timestamp']).sum()
print(f"Total duplicate rows: {duplicates_all}")
print(f"Duplicate timestamps: {timestamp_duplicates}")

# Identifying rows with negative values for 'volume' and 'close'
negative_volume_count = filled_df_filtered[filled_df_filtered['volume'] < 0].shape[0]
negative_close_count = filled_df_filtered[filled_df_filtered['close'] < 0].shape[0]
print(f"Rows with negative volume: {negative_volume_count}")
print(f"Rows with negative close: {negative_close_count}")
# Out:
# Total duplicate rows: 0
# Duplicate timestamps: 905
# Rows with negative volume: 0
# Rows with negative close: 0

# %%
# Identifying duplicate timestamps and selecting the rows
duplicates_by_timestamp = filled_df_filtered[filled_df_filtered.duplicated(subset=['timestamp'], keep=False)]

# Sorting by 'timestamp' to ensure duplicates are grouped together for viewing
sorted_duplicates = duplicates_by_timestamp.sort_values(by='timestamp')

# Displaying the first 100 duplicates
print(sorted_duplicates.head(100))
# Out:
#                 timestamp       low      high      open     close  \
# 64866 2022-12-16 14:00:00  16895.69  17085.53  16947.31  17034.07
# 64867 2022-12-16 14:00:00  16895.69  17085.53  16947.31  17034.07
# 64868 2022-12-16 14:00:00  16895.69  17085.53  16947.31  17034.07
# 64869 2022-12-16 15:00:00  16912.63  17035.93  17033.38  16972.18
# 64870 2022-12-16 15:00:00  16912.63  17035.93  17033.38  16972.18
# ...                   ...       ...       ...       ...       ...
# 64999 2022-12-19 14:00:00  16667.90  16765.23  16710.66  16736.58
# 65002 2022-12-19 14:00:00  16667.90  16765.23  16710.66  16736.58
# 65007 2022-12-19 15:00:00  16664.32  16742.31  16736.58  16666.54
# 65008 2022-12-19 15:00:00  16664.32  16742.31  16736.58  16666.54
# 65009 2022-12-19 15:00:00  16664.32  16742.31  16736.58  16666.54
#
#             volume        sma_30        rsi        macd  dia_open  ...  value  \
# 64866  3912.720814  17366.694667  33.864182 -148.420783   320.032  ...   29.0
# 64867  3912.720814  17366.694667  33.864182 -148.420783   320.032  ...   29.0
# 64868  3912.720814  17366.694667  33.864182 -148.420783   320.032  ...   29.0
# 64869  2082.466625  17342.487667  29.818510 -152.002796   321.265  ...   29.0
# 64870  2082.466625  17342.487667  29.818510 -152.002796   321.265  ...   29.0
# ...            ...           ...        ...         ...       ...  ...    ...
# 64999  1825.462473  16732.543000  49.339494   -0.680230   319.856  ...   29.0
# 65002  1825.462473  16732.543000  49.339494   -0.680230   319.856  ...   29.0
# 65007  1227.883617  16731.398333  34.246134   -6.383488   318.976  ...   29.0
# 65008  1227.883617  16731.398333  34.246134   -6.383488   318.976  ...   29.0
# 65009  1227.883617  16731.398333  34.246134   -6.383488   318.976  ...   29.0
#
#        classification     id  \
# 64866            Fear  731.0
# 64867            Fear  732.0
# 64868            Fear  733.0
# 64869            Fear  725.0
# 64870            Fear  726.0
# ...               ...    ...
# 64999            Fear  613.0
# 65002            Fear  616.0
# 65007            Fear  609.0
# 65008            Fear  610.0
# 65009            Fear  611.0
#
#                                                    title  \
# 64866  LQwD Fintech Releases Version 2 of its Bitcoin...
# 64867  LQwD Fintech Releases Version 2 of its Bitcoin...
# 64868  Web3 community shares tips for a successful Ga...
# 64869     Senators propose bill to end privacy in crypto
# 64870  Bitcoin Records Losses But Remains Above This ...
# ...                                                  ...
# 64999  Robert Reich Lists Crypto Among Zero-Sum Secto...
# 65002  Cathie Wood Goes Bargain-Hunting: 3 Stocks She...
# 65007  Ethereum Edges Higher But Remains Below This K...
# 65008  Down 62% This Year, This Growth Stock Is a No-...
# 65009  Binance U.S. Wins Bid To Buy Bankrupt Voyager ...
#
#                                                      url  sentiment_score  \
# 64866  https://www.prnewswire.com/news-releases/lqwd-...         0.201764
# 64867  https://www.newswire.ca/news-releases/lqwd-fin...         0.201764
# 64868  https://cointelegraph.com/news/web3-community-...         0.416001
# 64869  https://www.axios.com/2022/12/16/senate-bill-p...        -0.021590
# 64870  https://www.benzinga.com/markets/cryptocurrenc...        -0.184274
# ...                                                  ...              ...
# 64999  https://www.benzinga.com/analyst-ratings/analy...         0.031677
# 65002  https://www.fool.com/investing/2022/12/19/cath...         0.202212
# 65007  https://www.benzinga.com/markets/cryptocurrenc...        -0.059649
# 65008  https://www.fool.com/investing/2022/12/19/down...         0.260443
# 65009  https://www.forbes.com/sites/jonathanponciano/...        -0.019479
#
#        sentiment_interpretation                      author  \
# 64866          Somewhat_Bullish          LQwD FinTech Corp.
# 64867          Somewhat_Bullish          LQwD FinTech Corp.
# 64868                   Bullish                     Unknown
# 64869                   Neutral  Brady Dale, /authors/bdale
# 64870          Somewhat-Bearish                  Lisa Levin
# ...                         ...                         ...
# 64999                   Neutral                 Bhavik Nair
# 65002          Somewhat_Bullish               Rick Munarriz
# 65007                   Neutral                  Lisa Levin
# 65008          Somewhat_Bullish              Stefon Walters
# 65009                   Neutral           Jonathan Ponciano
#
#             timestamp_news    timestamp_rounded
# 64866  2022-12-16 14:00:00  2022-12-16 14:00:00
# 64867  2022-12-16 14:00:00  2022-12-16 14:00:00
# 64868  2022-12-16 13:50:25  2022-12-16 14:50:25
# 64869  2022-12-16 14:50:15  2022-12-16 15:50:15
# 64870  2022-12-16 14:38:28  2022-12-16 15:38:28
# ...                    ...                  ...
# 64999  2022-12-19 13:48:42  2022-12-19 14:48:42
# 65002  2022-12-19 13:30:00  2022-12-19 14:30:00
# 65007  2022-12-19 14:55:34  2022-12-19 15:55:34
# 65008  2022-12-19 14:45:00  2022-12-19 15:45:00
# 65009  2022-12-19 14:19:32  2022-12-19 15:19:32
#
# [100 rows x 57 columns]

# %%
# Assuming duplicates_by_timestamp contains all rows with duplicate timestamps
if not duplicates_by_timestamp.empty:
    first_duplicate_timestamp = duplicates_by_timestamp['timestamp'].min()
    last_duplicate_timestamp = duplicates_by_timestamp['timestamp'].max()
    print(f"First duplicate timestamp: {first_duplicate_timestamp}")
    print(f"Last duplicate timestamp: {last_duplicate_timestamp}")
else:
    print("No duplicates found.")
# Out:
# First duplicate timestamp: 2022-12-16 14:00:00
# Last duplicate timestamp: 2023-12-31 23:00:00

# %%
# This leads us to believe the duplicates came from merging the btc news dataset (start 2022, end 2023)

# %%
# Group the DataFrame by 'timestamp' and check if all values within each group are identical
duplicate_groups = duplicates_by_timestamp.groupby('timestamp')

# Initialize a dictionary to hold the result
duplicate_analysis = {'timestamp': [], 'identical_values': []}

for name, group in duplicate_groups:
    # Assuming at least one duplicate (i.e., group size > 1), compare all rows in the group
    if group.shape[0] > 1:
        # Drop the 'timestamp' column for comparison, as we already know it's identical within the group
        without_timestamp = group.drop(columns='timestamp')
        # Compare all rows in the group (excluding the timestamp) to the first row
        identical_rows = without_timestamp.eq(without_timestamp.iloc[0]).all().all()
        # Record the analysis
        duplicate_analysis['timestamp'].append(name)
        duplicate_analysis['identical_values'].append(identical_rows)

# Convert the analysis result to a DataFrame for easy viewing
analysis_df = pd.DataFrame(duplicate_analysis)

# Check the analysis DataFrame to see the result
print(analysis_df)
# Out:
#               timestamp  identical_values
# 0   2022-12-16 14:00:00             False
# 1   2022-12-16 15:00:00             False
# 2   2022-12-16 16:00:00             False
# 3   2022-12-16 18:00:00             False
# 4   2022-12-16 20:00:00             False
# ..                  ...               ...
# 347 2023-12-31 05:00:00             False
# 348 2023-12-31 11:00:00             False
# 349 2023-12-31 12:00:00             False
# 350 2023-12-31 20:00:00             False
# 351 2023-12-31 23:00:00             False
#
# [352 rows x 2 columns]

# %% [markdown]
# ### We keep 2 datasets, as news was grouped per hour. The identical values mean different articles were published in the same hour.

# %%
# Save the DataFrame with duplicates
filled_df_filtered.to_csv('data/filled_df_filtered_with_duplicates.csv', index=False)

# Remove duplicate timestamps, keeping the first occurrence
# This results in a dataset without duplicates where for each timestamp, only the first occurrence is kept
filled_df_filtered_no_duplicates = filled_df_filtered.drop_duplicates(subset=['timestamp'], keep='first')

# Save the DataFrame without duplicates
# filled_df_filtered_no_duplicates.csv for the dataset with duplicates removed,
# keeping only the first occurrence of each timestamp.
filled_df_filtered_no_duplicates.to_csv('data/filled_df_filtered_no_duplicates.csv', index=False)

# %% [markdown]
# # Verification

# %%
# Check for duplicate timestamps in the no duplicates DataFrame
duplicate_timestamps_check = filled_df_filtered_no_duplicates.duplicated(subset=['timestamp']).sum()

# Print the result to confirm if duplicates exist
print(f"Number of duplicate timestamps in the no duplicates DataFrame: {duplicate_timestamps_check}")
# Out:
# Number of duplicate timestamps in the no duplicates DataFrame: 0
