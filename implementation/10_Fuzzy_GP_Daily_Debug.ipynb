# %% [markdown]
# ## Imports

# %%
import pandas as pd
from pathlib import Path
from simpful.gp_fuzzy_system.gp_evolution import genetic_algorithm_loop
from simpful.gp_fuzzy_system.auto_lvs import FuzzyLinguisticVariableProcessor
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import MinMaxScaler
# Out:
# /Users/nikhilrazab-sekh/Desktop/simpful_btc/implementation/new_env/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %% [markdown]
# ## Load Data

# %%
import os
import pandas as pd
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import MinMaxScaler

# Paths to the prepped data files
base_path = './daily_data/'
scaled_path = os.path.join(base_path, 'scaled')

# Create the scaled directory if it doesn't exist
os.makedirs(scaled_path, exist_ok=True)

X_train_path = base_path + 'X_train.csv'
X_test_path = base_path + 'X_test.csv'
y_train_path = base_path + 'y_train.csv'
y_test_path = base_path + 'y_test.csv'

# Loading the datasets
X_train = pd.read_csv(X_train_path)
X_test = pd.read_csv(X_test_path)
y_train = pd.read_csv(y_train_path)
y_test = pd.read_csv(y_test_path)

# Rename the column in y_train to 'target'
y_train.rename(columns={'close': 'target'}, inplace=True)

# Rename the column in y_test to 'target'
y_test.rename(columns={'close': 'target'}, inplace=True)

# Impute missing values in 'value' and 'classification_numerical' columns
imputer = SimpleImputer(strategy='mean')
X_train[['value', 'classification_numerical']] = imputer.fit_transform(X_train[['value', 'classification_numerical']])

# Verify that there are no NaN values left
print("NaN values in X_train after imputation:\n", X_train.isna().sum().sum())

# Check for extreme values in the data
print("Extreme values in X_train:", (X_train > 1e9).sum().sum())

# Exclude non-numerical columns before scaling
columns_to_scale = X_train.columns  # All columns in X_train are numerical

# Initialize the scaler for the features
scaler_X = MinMaxScaler()

# Scale 'X' features
x_train_scaled = scaler_X.fit_transform(X_train[columns_to_scale])
x_test_scaled = scaler_X.transform(X_test[columns_to_scale])

# Initialize a separate scaler for the target variable
scaler_y = MinMaxScaler()

# Scale 'y' (the target variable)
y_train_scaled = scaler_y.fit_transform(y_train.values.reshape(-1, 1)).flatten()
y_test_scaled = scaler_y.transform(y_test.values.reshape(-1, 1)).flatten()

# Paths to save the scaled data
scaled_X_train_path = os.path.join(scaled_path, 'X_train_scaled.csv')
scaled_X_test_path = os.path.join(scaled_path, 'X_test_scaled.csv')
scaled_y_train_path = os.path.join(scaled_path, 'y_train_scaled.csv')
scaled_y_test_path = os.path.join(scaled_path, 'y_test_scaled.csv')

# Save the preprocessed and scaled data to the 'scaled' directory
pd.DataFrame(x_train_scaled, columns=columns_to_scale).to_csv(scaled_X_train_path, index=False)
pd.DataFrame(x_test_scaled, columns=columns_to_scale).to_csv(scaled_X_test_path, index=False)
pd.DataFrame(y_train_scaled, columns=['target']).to_csv(scaled_y_train_path, index=False)
pd.DataFrame(y_test_scaled, columns=['target']).to_csv(scaled_y_test_path, index=False)
# Out:
# NaN values in X_train after imputation:
#  0
# Extreme values in X_train: 2367

# %% [markdown]
# ## Further Processing

# %%
# Initialize the FuzzyLinguisticVariableProcessor with the scaled X_train path
exclude_columns = 'month,day,hour'
terms_dict_path = './terms/terms_dict.py'
verbose = True

processor = FuzzyLinguisticVariableProcessor(
    file_path=scaled_X_train_path,  # Use the scaled data path
    terms_dict_path=terms_dict_path, 
    verbose=verbose, 
    exclude_columns=exclude_columns.split(','),
    mf_type='sigmoid',
)
variable_store = processor.process_dataset()
# Out:
# Defined sigmoid fuzzy set for term 'VERY_LOW' with mean: 0.01897952633422215, slope: 0.06209609300520463
# Defined sigmoid fuzzy set for term 'LOW' with mean: 0.12419218601040927, slope: 0.14019963555809287
# Defined sigmoid fuzzy set for term 'MEDIUM' with mean: 0.2993787974504079, slope: 0.23164142437871277
# Defined sigmoid fuzzy set for term 'HIGH' with mean: 0.5874750347678348, slope: 0.26648731966127504
# Defined sigmoid fuzzy set for term 'VERY_HIGH' with mean: 0.8323534367729579, slope: 0.2062624826160826
# Created linguistic variable for column 'open' with 5 terms
# Defined sigmoid fuzzy set for term 'VERY_LOW' with mean: 0.04314046190211634, slope: 0.05267054070660693
# Defined sigmoid fuzzy set for term 'LOW' with mean: 0.10534108141321386, slope: 0.07052469727328028
# Defined sigmoid fuzzy set for term 'MEDIUM' with mean: 0.18418985644867691, slope: 0.11443813441386974
# Defined sigmoid fuzzy set for term 'HIGH' with mean: 0.33421735024095334, slope: 0.24128127397758642
# Defined sigmoid fuzzy set for term 'VERY_HIGH' with mean: 0.6667524044038498, slope: 0.33289132487952333
# Created linguistic variable for column 'volume' with 5 terms
# Defined sigmoid fuzzy set for term 'VERY_LOW' with mean: 0.01871374012257411, slope: 0.06207331513678956
# Defined sigmoid fuzzy set for term 'LOW' with mean: 0.12414663027357913, slope: 0.13719782291225086
# Defined sigmoid fuzzy set for term 'MEDIUM' with mean: 0.2931093859470758, slope: 0.23142055998165975
# Defined sigmoid fuzzy set for term 'HIGH' with mean: 0.5869877502368986, slope: 0.2703286381131079
# Defined sigmoid fuzzy set for term 'VERY_HIGH' with mean: 0.8337666621732917, slope: 0.20650612488155068
# Created linguistic variable for column 'sma_30' with 5 terms
# Defined sigmoid fuzzy set for term 'VERY_LOW' with mean: 0.23190426973023276, slope: 0.19014813126186267
# Defined sigmoid fuzzy set for term 'LOW' with mean: 0.38029626252372534, slope: 0.13222425985631336
# Defined sigmoid fuzzy set for term 'MEDIUM' with mean: 0.4963527894428595, slope: 0.119937957667243
# Defined sigmoid fuzzy set for term 'HIGH' with mean: 0.6201721778582113, slope: 0.14170433919202066
# Defined sigmoid fuzzy set for term 'VERY_HIGH' with mean: 0.7797614678269008, slope: 0.18991391107089434
# Created linguistic variable for column 'rsi' with 5 terms
# Defined sigmoid fuzzy set for term 'VERY_LOW' with mean: 0.319302807001313, slope: 0.23818853991388236
# Defined sigmoid fuzzy set for term 'LOW' with mean: 0.4763770798277647, slope: 0.11322836210814227
# Defined sigmoid fuzzy set for term 'MEDIUM' with mean: 0.5457595312175976, slope: 0.06604608657547065
# Defined sigmoid fuzzy set for term 'HIGH' with mean: 0.608469252978706, slope: 0.09589463783553703
# Defined sigmoid fuzzy set for term 'VERY_HIGH' with mean: 0.7375488068886716, slope: 0.195765373510647
# Created linguistic variable for column 'macd' with 5 terms
# Defined sigmoid fuzzy set for term 'VERY_LOW' with mean: 0.08924995410953229, slope: 0.12383519845358491
# Defined sigmoid fuzzy set for term 'LOW' with mean: 0.24767039690716983, slope: 0.17394497563793818
# Defined sigmoid fuzzy set for term 'MEDIUM' with mean: 0.43713990538540864, slope: 0.17947680879493877
# Defined sigmoid fuzzy set for term 'HIGH' with mean: 0.6066240144970474, slope: 0.22938192685932016
# Defined sigmoid fuzzy set for term 'VERY_HIGH' with mean: 0.895903759104049, slope: 0.1966879927514762
# Created linguistic variable for column 'dia_close' with 5 terms
# Defined sigmoid fuzzy set for term 'VERY_LOW' with mean: 0.0028293972346788055, slope: 0.04906100975573499
# Defined sigmoid fuzzy set for term 'LOW' with mean: 0.09812201951146998, slope: 0.08395695106541218
# Defined sigmoid fuzzy set for term 'MEDIUM' with mean: 0.17074329936550317, slope: 0.09311425849590668
# Defined sigmoid fuzzy set for term 'HIGH' with mean: 0.28435053650328335, slope: 0.20529600638211026
# Defined sigmoid fuzzy set for term 'VERY_HIGH' with mean: 0.5813353121297237, slope: 0.3578247317483583
# Created linguistic variable for column 'dia_volume' with 5 terms
# Defined sigmoid fuzzy set for term 'VERY_LOW' with mean: 0.150055159892874, slope: 0.12014411645347015
# Defined sigmoid fuzzy set for term 'LOW' with mean: 0.2402882329069403, slope: 0.14426886468815464
# Defined sigmoid fuzzy set for term 'MEDIUM' with mean: 0.4385928892691833, slope: 0.22910855782615921
# Defined sigmoid fuzzy set for term 'HIGH' with mean: 0.6985053485592587, slope: 0.1963015790018583
# Defined sigmoid fuzzy set for term 'VERY_HIGH' with mean: 0.8311960472728999, slope: 0.15074732572037053
# Created linguistic variable for column 'gld_close' with 5 terms
# Defined sigmoid fuzzy set for term 'VERY_LOW' with mean: 0.0013922639501345075, slope: 0.028255000031304642
# Defined sigmoid fuzzy set for term 'LOW' with mean: 0.056510000062609284, slope: 0.05086980719956762
# Defined sigmoid fuzzy set for term 'MEDIUM' with mean: 0.10313187834926975, slope: 0.07566478478684559
# Defined sigmoid fuzzy set for term 'HIGH' with mean: 0.20783956963630046, slope: 0.3811652802772703
# Defined sigmoid fuzzy set for term 'VERY_HIGH' with mean: 0.8654624389038104, slope: 0.39608021518184977
# Created linguistic variable for column 'gld_volume' with 5 terms
# Defined sigmoid fuzzy set for term 'VERY_LOW' with mean: 0.1070989625377157, slope: 0.14696225576323962
# Defined sigmoid fuzzy set for term 'LOW' with mean: 0.29392451152647925, slope: 0.1722530210174284
# Defined sigmoid fuzzy set for term 'MEDIUM' with mean: 0.4516050045725725, slope: 0.19652408250201575
# Defined sigmoid fuzzy set for term 'HIGH' with mean: 0.6869726765305108, slope: 0.21851492545463583
# Defined sigmoid fuzzy set for term 'VERY_HIGH' with mean: 0.8886348554818442, slope: 0.15651366173474462
# Created linguistic variable for column 'spy_close' with 5 terms
# Defined sigmoid fuzzy set for term 'VERY_LOW' with mean: 0.005277373371821912, slope: 0.07235932473577453
# Defined sigmoid fuzzy set for term 'LOW' with mean: 0.14471864947154905, slope: 0.11291924711513546
# Defined sigmoid fuzzy set for term 'MEDIUM' with mean: 0.23111586760209282, slope: 0.10849480627106217
# Defined sigmoid fuzzy set for term 'HIGH' with mean: 0.3617082620136734, slope: 0.21673357881296146
# Defined sigmoid fuzzy set for term 'VERY_HIGH' with mean: 0.6645830252280157, slope: 0.31914586899316333
# Created linguistic variable for column 'spy_volume' with 5 terms
# Defined sigmoid fuzzy set for term 'VERY_LOW' with mean: 0.01756151464656831, slope: 0.07588513162951942
# Defined sigmoid fuzzy set for term 'LOW' with mean: 0.15177026325903883, slope: 0.20697543000420224
# Defined sigmoid fuzzy set for term 'MEDIUM' with mean: 0.4315123746549728, slope: 0.2590835140081985
# Defined sigmoid fuzzy set for term 'HIGH' with mean: 0.6699372912754359, slope: 0.25585872199177295
# Defined sigmoid fuzzy set for term 'VERY_HIGH' with mean: 0.9432298186385186, slope: 0.16503135436228206
# Created linguistic variable for column 'federal_funds_rate_daily' with 5 terms
# Defined sigmoid fuzzy set for term 'VERY_LOW' with mean: 0.07731561654957052, slope: 0.16387609145229168
# Defined sigmoid fuzzy set for term 'LOW' with mean: 0.32775218290458336, slope: 0.1814801128205294
# Defined sigmoid fuzzy set for term 'MEDIUM' with mean: 0.4402758421906293, slope: 0.14784541336077037
# Defined sigmoid fuzzy set for term 'HIGH' with mean: 0.6234430096261241, slope: 0.18271185735820356
# Defined sigmoid fuzzy set for term 'VERY_HIGH' with mean: 0.8056995569070364, slope: 0.18827849518693796
# Created linguistic variable for column 'treasury_yield_daily' with 5 terms
# Defined sigmoid fuzzy set for term 'VERY_LOW' with mean: 0.08130256899004555, slope: 0.11971118796429218
# Defined sigmoid fuzzy set for term 'LOW' with mean: 0.23942237592858437, slope: 0.1403143196276281
# Defined sigmoid fuzzy set for term 'MEDIUM' with mean: 0.3619312082453018, slope: 0.19752599229265533
# Defined sigmoid fuzzy set for term 'HIGH' with mean: 0.634474360513895, slope: 0.2633397326148003
# Defined sigmoid fuzzy set for term 'VERY_HIGH' with mean: 0.8886106734749024, slope: 0.18276281974305247
# Created linguistic variable for column 'cpi_monthly' with 5 terms
# Defined sigmoid fuzzy set for term 'VERY_LOW' with mean: 0.07550799781476544, slope: 0.18076374695050348
# Defined sigmoid fuzzy set for term 'LOW' with mean: 0.36152749390100697, slope: 0.2086187181837168
# Defined sigmoid fuzzy set for term 'MEDIUM' with mean: 0.49274543418219907, slope: 0.13463376359268212
# Defined sigmoid fuzzy set for term 'HIGH' with mean: 0.6307950210863712, slope: 0.1558429749655562
# Defined sigmoid fuzzy set for term 'VERY_HIGH' with mean: 0.8044313841133115, slope: 0.1846024894568145
# Created linguistic variable for column 'durables_monthly' with 5 terms
# Defined sigmoid fuzzy set for term 'VERY_LOW' with mean: 0.07045311514943005, slope: 0.23283259436270595
# Defined sigmoid fuzzy set for term 'LOW' with mean: 0.4656651887254119, slope: 0.2724061287230863
# Defined sigmoid fuzzy set for term 'MEDIUM' with mean: 0.6152653725956027, slope: 0.14501743653942964
# Defined sigmoid fuzzy set for term 'HIGH' with mean: 0.7557000618042712, slope: 0.1446086399090571
# Defined sigmoid fuzzy set for term 'VERY_HIGH' with mean: 0.9044826524137168, slope: 0.12214996909786441
# Created linguistic variable for column 'nonfarm_payroll_monthly' with 5 terms
# Defined sigmoid fuzzy set for term 'LOW' with mean: 0.1992692662517229, slope: 0.24412204024344586
# Defined sigmoid fuzzy set for term 'MEDIUM' with mean: 0.4882440804868917, slope: 0.22829623422373146
# Defined sigmoid fuzzy set for term 'HIGH' with mean: 0.6558617346991858, slope: 0.22085604754844168
# Defined sigmoid fuzzy set for term 'VERY_HIGH' with mean: 0.9299561755837751, slope: 0.17206913265040708
# Created linguistic variable for column 'real_gdp_per_capita_quarterly' with 4 terms
# Failed to create linguistic variable for column 'real_gdp_quarterly' with at least 2 terms
# Defined sigmoid fuzzy set for term 'VERY_LOW' with mean: 0.0742756252335492, slope: 0.11333560422370055
# Defined sigmoid fuzzy set for term 'LOW' with mean: 0.2266712084474011, slope: 0.1463280807987576
# Defined sigmoid fuzzy set for term 'MEDIUM' with mean: 0.36693178683106437, slope: 0.14941315605576072
# Defined sigmoid fuzzy set for term 'HIGH' with mean: 0.5254975205589225, slope: 0.2221139864016972
# Defined sigmoid fuzzy set for term 'VERY_HIGH' with mean: 0.8111597596344587, slope: 0.23725123972053874
# Created linguistic variable for column 'retail_sales_monthly' with 5 terms
# Defined sigmoid fuzzy set for term 'VERY_LOW' with mean: 0.026522446289469565, slope: 0.05587451609850814
# Defined sigmoid fuzzy set for term 'LOW' with mean: 0.11174903219701628, slope: 0.11807849681065986
# Defined sigmoid fuzzy set for term 'MEDIUM' with mean: 0.2626794399107893, slope: 0.24876683622728585
# Defined sigmoid fuzzy set for term 'HIGH' with mean: 0.609282704651588, slope: 0.3342819774175966
# Defined sigmoid fuzzy set for term 'VERY_HIGH' with mean: 0.9312433947459825, slope: 0.19535864767420602
# Created linguistic variable for column 'unemployment_monthly' with 5 terms
# Failed to create linguistic variable for column 'central_bank_policy_rate_prcnt' with at least 2 terms
# Defined sigmoid fuzzy set for term 'VERY_LOW' with mean: 6.848733961394544e-08, slope: 0.04438940107688153
# Defined sigmoid fuzzy set for term 'LOW' with mean: 0.08877880215376306, slope: 0.15306824931872368
# Defined sigmoid fuzzy set for term 'MEDIUM' with mean: 0.306136567124787, slope: 0.45262554654141324
# Defined sigmoid fuzzy set for term 'HIGH' with mean: 0.9940298952365896, slope: 0.3469317164376065
# Created linguistic variable for column 'domestic_credit_gdp' with 4 terms
# Defined sigmoid fuzzy set for term 'VERY_LOW' with mean: 0.20874529133248793, slope: 0.2814795974918139
# Defined sigmoid fuzzy set for term 'LOW' with mean: 0.5629591949836278, slope: 0.25863238987837
# Defined sigmoid fuzzy set for term 'MEDIUM' with mean: 0.7260100710892279, slope: 0.2094302852714255
# Defined sigmoid fuzzy set for term 'HIGH' with mean: 0.9818197655264788, slope: 0.13699496445538606
# Created linguistic variable for column 'foreign_direct_investment_value' with 4 terms
# Failed to create linguistic variable for column 'gdp_growth_annual_prcnt' with at least 2 terms
# Defined sigmoid fuzzy set for term 'VERY_LOW' with mean: 0.00404075105748984, slope: 0.08351319400359707
# Defined sigmoid fuzzy set for term 'LOW' with mean: 0.16702638800719413, slope: 0.12737547687283612
# Defined sigmoid fuzzy set for term 'MEDIUM' with mean: 0.2587917048031621, slope: 0.09098205267845173
# Defined sigmoid fuzzy set for term 'HIGH' with mean: 0.3489904933640976, slope: 0.3706041474158198
# Defined sigmoid fuzzy set for term 'VERY_HIGH' with mean: 0.9999999996348017, slope: 0.3255047533179512
# Created linguistic variable for column 'inflation_rate_value' with 5 terms
# Failed to create linguistic variable for column 'individuals_using_the_internet_prcnt_of_population' with at least 2 terms
# Defined sigmoid fuzzy set for term 'VERY_LOW' with mean: 0.0286333640989036, slope: 0.2050346097256878
# Defined sigmoid fuzzy set for term 'LOW' with mean: 0.4100692194513756, slope: 0.2011539292576227
# Defined sigmoid fuzzy set for term 'MEDIUM' with mean: 0.430941222614149, slope: 0.18690840236303005
# Defined sigmoid fuzzy set for term 'HIGH' with mean: 0.7838860241774357, slope: 0.284528897938806
# Defined sigmoid fuzzy set for term 'VERY_HIGH' with mean: 0.999999018491761, slope: 0.10805698791128215
# Created linguistic variable for column 'mobile_cellular_subscriptions_per_100_people' with 5 terms
# Defined sigmoid fuzzy set for term 'VERY_LOW' with mean: 3.3641883573760038e-06, slope: 0.2866213597458022
# Defined sigmoid fuzzy set for term 'LOW' with mean: 0.5732427194916044, slope: 0.36013201727855493
# Defined sigmoid fuzzy set for term 'MEDIUM' with mean: 0.7202673987454672, slope: 0.20906146580167423
# Defined sigmoid fuzzy set for term 'HIGH' with mean: 0.9913656510949529, slope: 0.1398663006272664
# Created linguistic variable for column 'personal_remittances_received_prcnt_of_gdp' with 4 terms
# Failed to create linguistic variable for column 'stock_market_index_value' with at least 2 terms
# Failed to create linguistic variable for column 'tariffs_value' with at least 2 terms
# Defined sigmoid fuzzy set for term 'VERY_LOW' with mean: 0.02419482810609577, slope: 0.053825509744201194
# Defined sigmoid fuzzy set for term 'MEDIUM' with mean: 0.10765101948840239, slope: 0.38489430538303354
# Defined sigmoid fuzzy set for term 'HIGH' with mean: 0.7939834388721628, slope: 0.44617419951095316
# Defined sigmoid fuzzy set for term 'VERY_HIGH' with mean: 0.9999994185103087, slope: 0.10300828056391859
# Created linguistic variable for column 'total_public_debt_gdp_value' with 4 terms
# Failed to create linguistic variable for column 'trade_balance_value' with at least 2 terms
# Defined sigmoid fuzzy set for term 'VERY_LOW' with mean: 0.0693105500876047, slope: 0.4291903345637939
# Defined sigmoid fuzzy set for term 'LOW' with mean: 0.8583806691275878, slope: 0.4045871646117281
# Defined sigmoid fuzzy set for term 'MEDIUM' with mean: 0.8784848793110609, slope: 0.07079365144289035
# Defined sigmoid fuzzy set for term 'HIGH' with mean: 0.9999679720133685, slope: 0.060757560344469774
# Created linguistic variable for column 'trade_in_services_value' with 4 terms
# Failed to create linguistic variable for column 'unemployment_rate_value' with at least 2 terms
# Failed to create linguistic variable for column 'value' with at least 2 terms
# Failed to create linguistic variable for column 'classification_numerical' with at least 2 terms

# %%
# Define the parameters
population_size = 10
max_generations = 4
mutation_rate = 0.5
crossover_rate = 0.8
selection_method = 'hybrid'
tournament_size = 3
elitism_rate = 0.15
max_rules = 7
min_rules = 3
verbose = False

# Run the genetic algorithm
best_system, best_fitness_per_generation, average_fitness_per_generation = genetic_algorithm_loop(population_size,
    max_generations, x_train_scaled, y_train_scaled, variable_store, selection_method,
    tournament_size, crossover_rate, mutation_rate, elitism_rate, max_rules, min_rules, verbose)
# Out:
# Generations:   0%|                                                                                                                                                              | 0/4 [00:00<?, ?gen/s]
# --- Error Log ---
# Error adding rule: IF (dia_close IS LOW) AND (foreign_direct_investment_value IS LOW) OR (durables_monthly IS LOW) OR (dia_volume IS MEDIUM) OR (trade_in_services_value IS HIGH) THEN (PricePrediction IS PricePrediction)
# Exception: ERROR: badly formatted rule, please check capitalization and syntax.
#  ---- PROBLEMATIC RULE:
# (dia_close IS LOW) AND (foreign_direct_investment_value IS LOW) OR (durables_monthly IS LOW) OR (dia_volume IS MEDIUM) OR (trade_in_services_value IS HIGH)
# --- End of Error Log ---
# Generations:  25%|█████████████████████████████████████▎                                                                                                               | 1/4 [03:09<09:29, 189.84s/gen]
